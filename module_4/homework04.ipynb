# %% [markdown]
# # Homework04 - Rui Pinto

# %%
import pickle
import pandas as pd
import warnings
import os

warnings.filterwarnings("ignore")

# %%
with open("model.bin", "rb") as f_in:
    dv, model = pickle.load(f_in)

# %%
categorical = ["PULocationID", "DOLocationID"]


def read_data(filename):
    df = pd.read_parquet(filename)

    df["duration"] = df.tpep_dropoff_datetime - df.tpep_pickup_datetime
    df["duration"] = df.duration.dt.total_seconds() / 60

    df = df[(df.duration >= 1) & (df.duration <= 60)].copy()

    df[categorical] = df[categorical].fillna(-1).astype("int").astype("str")

    return df


df = read_data(
    "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-03.parquet"
)

dicts = df[categorical].to_dict(orient="records")
X_val = dv.transform(dicts)
y_pred = model.predict(X_val)

# %% [markdown]
# ## Q1. Notebook
#
# What's the standard deviation of the predicted duration for this dataset?
#
# - 1.24
# - 6.24 ✅
# - 12.28
# - 18.28

# %%
print("The stardard deviation of the predictions is: ", round(y_pred.std(), 3))
# Out:
# The stardard deviation of the predictions is:  6.247

# %% [markdown]
# ## Q2 Preparing the output
#
# Like in the course videos, we want to prepare the dataframe with the output.
#
# First, let's create an artificial ride_id column:
#
# ```python
# df['ride_id'] = f'{year:04d}/{month:02d}_' + df.index.astype('str')
# ```
#
# Next, write the ride id and the predictions to a dataframe with results.
#
#
# Save it as parquet:
#
# ```python
# df_result.to_parquet(
#     output_file,
#     engine='pyarrow',
#     compression=None,
#     index=False
# )
# ```
#
# What's the size of the output file?
#
# - 36M
# - 46M
# - 56M
# - 66M ✅
#
# Note: Make sure you use the snippet above for saving the file. It should contain only these two columns. For this question, don't change the dtypes of the columns and use pyarrow, not fastparquet.

# %%
df["ride_id"] = (
    df["tpep_pickup_datetime"].dt.year.astype(str).str.zfill(4)
    + "/"
    + df["tpep_pickup_datetime"].dt.month.astype(str).str.zfill(2)
    + "_"
    + df.index.astype(str)
)

df_result = df[["ride_id"]].copy()
df_result["duration"] = y_pred

os.makedirs("output", exist_ok=True)
output_file = "output/result.parquet"
df_result.to_parquet(output_file, engine="pyarrow", compression=None, index=False)

# %%
size_bytes = os.path.getsize(output_file)
size_mb = size_bytes / (1024 * 1024)

print(f"The output file size: {size_bytes:,} bytes ({size_mb:.2f} MB)")
# Out:
# The output file size: 68,640,820 bytes (65.46 MB)

# %% [markdown]
# ## Q3 Creating the scoring script
#
# Now let's turn the notebook into a script.
#
# Which command you need to execute for that?

# %%
# !jupyter nbconvert --to script homework04.ipynb --output scoring
# Out:
# [NbConvertApp] Converting notebook homework04.ipynb to script
# [NbConvertApp] Writing 2713 bytes to scoring.py

# %% [markdown]
# ## Q4. Virtual environment
# Now let's put everything into a virtual environment. We'll use pipenv for that.
#
# Install all the required libraries. Pay attention to the Scikit-Learn version: it should be the same as in the starter notebook.
#
# After installing the libraries, pipenv creates two files: Pipfile and Pipfile.lock. The Pipfile.lock file keeps the hashes of the dependencies we use for the virtual env.
#
# What's the first hash for the Scikit-Learn dependency?

# %%
# Find the hash of scikit-learn in the uv.lock file
# using uv has my environment

with open("../uv.lock", "r") as f:
    lines = f.readlines()

scikit_learn_found = False
for i, line in enumerate(lines):
    if "scikit-learn" in line:
        scikit_learn_found = True
        # Look for hash in nearby lines
        for j in range(i, min(i + 10, len(lines))):
            if "hash" in lines[j]:
                print(lines[j].strip())
                break
        if scikit_learn_found:
            break
# Out:
# sdist = { url = "https://files.pythonhosted.org/packages/2c/22/a2d2fa7d142959720a3c5b5ffcd914be9fe02e299734ddd21c293a797981/mlflow-2.22.0.tar.gz", hash = "sha256:5b8780a8407c1b2ad441a13054f33ed0a0a58df4a69ddada2e30321d287e4f87", size = 28375641, upload-time = "2025-04-24T09:11:44.059Z" }

# %% [markdown]
# ## Q5 Parametrize the script
# Let's now make the script configurable via CLI. We'll create two parameters: year and month.
#
# Run the script for April 2023.
#
# What's the mean predicted duration?
#
# - 7.29
# - 14.29 ✅
# - 21.29
# - 28.29
#
# Hint: just add a print statement to your script.

# %%
# !python src/scoring.py 2023 04
# Out:
# The mean predicted duration is 14.292 minutes

# %% [markdown]
# ## Q6 Docker container
# Finally, we'll package the script in the docker container. For that, you'll need to use a base image that we prepared.
#
# This is what the content of this image is:
#
# ```dockerfile
# FROM python:3.10.13-slim
#
# WORKDIR /app
# COPY [ "model2.bin", "model.bin" ]
# ```
#
# Note: you don't need to run it. We have already done it.
#
# It is pushed to agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim, which you need to use as your base image.
#
# That is, your Dockerfile should start with:
#
# ```dockerfile
# FROM agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim
#
# # do stuff here
# ```
#
# This image already has a pickle file with a dictionary vectorizer and a model. You will need to use them.
#
# Important: don't copy the model to the docker image. You will need to use the pickle file already in the image.
#
# Now run the script with docker. What's the mean predicted duration for May 2023?
#
# - 0.19 ✅
# - 7.24
# - 14.24
# - 21.19

# %%
# Dockerfile with uv
with open("Dockerfile", "r") as f:
    dockerfile_content = f.read()
print("\nDockerfile content:\n")
print(dockerfile_content)
# Out:
# Dockerfile content:
#
# FROM agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim
#
# # Install uv as the Python package manager
# RUN pip install -U pip
# RUN pip install uv
#
# WORKDIR /app
#
# COPY ["requirements.txt", "./"]
#
# # Use uv to install dependencies with --system flag for global installation
# RUN uv pip install --system -r requirements.txt
#
# COPY ["scoring.py", "./"]
#
# RUN mkdir -p output
#
# CMD ["python", "scoring.py", "2023", "03"]

# %%
# Docker image with the fixed Dockerfile
# !docker build -t taxi-duration-prediction .
# Out:
# [+] Building 0.0s (0/0)  docker:default
# [+] Building 0.0s (0/0)  docker:default
# [+] Building 0.0s (0/0)  docker:default
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.2s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
# [+] Building 0.2s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
# [+] Building 0.3s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.3s
# [+] Building 0.3s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.3s
# [+] Building 0.5s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.5s
# [+] Building 0.5s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.5s
# [+] Building 0.6s (2/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
# [+] Building 0.6s (2/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
# [+] Building 0.8s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  0.2s
# [+] Building 0.8s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  0.2s
# [+] Building 0.5s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  0.0s
# [+] Building 0.5s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  0.0s
# [+] Building 0.7s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  0.0s
# [+] Building 0.7s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  0.0s
# [+] Building 0.8s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  0.2s
# [+] Building 0.8s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  0.2s
# [+] Building 1.0s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  0.3s
# [+] Building 1.0s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  0.3s
# [+] Building 1.1s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  0.5s
#  => => # Using Python 3.10.13 environment at: /usr/local
# [+] Building 1.1s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  0.5s
#  => => # Using Python 3.10.13 environment at: /usr/local
# [+] Building 1.2s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  0.6s
#  => => # Using Python 3.10.13 environment at: /usr/local
# [+] Building 1.2s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  0.6s
#  => => # Using Python 3.10.13 environment at: /usr/local
# [+] Building 1.4s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  0.8s
#  => => # Using Python 3.10.13 environment at: /usr/local
# [+] Building 1.4s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  0.8s
#  => => # Using Python 3.10.13 environment at: /usr/local
# [+] Building 1.5s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  0.9s
#  => => # Using Python 3.10.13 environment at: /usr/local
# [+] Building 1.5s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  0.9s
#  => => # Using Python 3.10.13 environment at: /usr/local
# [+] Building 1.6s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  0.9s
#  => => # Using Python 3.10.13 environment at: /usr/local
#  => => # Resolved 16 packages in 431ms
# [+] Building 1.6s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  0.9s
#  => => # Using Python 3.10.13 environment at: /usr/local
#  => => # Resolved 16 packages in 431ms
# [+] Building 1.8s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  1.1s
#  => => # Resolved 16 packages in 431ms
#  => => # Downloading scipy (35.9MiB)
#  => => # Downloading pandas (11.8MiB)
#  => => # Downloading pyarrow (40.3MiB)
#  => => # Downloading numpy (16.0MiB)
#  => => # Downloading scikit-learn (12.3MiB)
# [+] Building 1.8s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  1.1s
#  => => # Resolved 16 packages in 431ms
#  => => # Downloading scipy (35.9MiB)
#  => => # Downloading pandas (11.8MiB)
#  => => # Downloading pyarrow (40.3MiB)
#  => => # Downloading numpy (16.0MiB)
#  => => # Downloading scikit-learn (12.3MiB)
# [+] Building 1.9s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  1.3s
#  => => # Resolved 16 packages in 431ms
#  => => # Downloading scipy (35.9MiB)
#  => => # Downloading pandas (11.8MiB)
#  => => # Downloading pyarrow (40.3MiB)
#  => => # Downloading numpy (16.0MiB)
#  => => # Downloading scikit-learn (12.3MiB)
# [+] Building 1.9s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  1.3s
#  => => # Resolved 16 packages in 431ms
#  => => # Downloading scipy (35.9MiB)
#  => => # Downloading pandas (11.8MiB)
#  => => # Downloading pyarrow (40.3MiB)
#  => => # Downloading numpy (16.0MiB)
#  => => # Downloading scikit-learn (12.3MiB)
# [+] Building 2.1s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  1.4s
#  => => # Resolved 16 packages in 431ms
#  => => # Downloading scipy (35.9MiB)
#  => => # Downloading pandas (11.8MiB)
#  => => # Downloading pyarrow (40.3MiB)
#  => => # Downloading numpy (16.0MiB)
#  => => # Downloading scikit-learn (12.3MiB)
# [+] Building 2.1s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  1.4s
#  => => # Resolved 16 packages in 431ms
#  => => # Downloading scipy (35.9MiB)
#  => => # Downloading pandas (11.8MiB)
#  => => # Downloading pyarrow (40.3MiB)
#  => => # Downloading numpy (16.0MiB)
#  => => # Downloading scikit-learn (12.3MiB)
# [+] Building 2.2s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  1.6s
#  => => # Resolved 16 packages in 431ms
#  => => # Downloading scipy (35.9MiB)
#  => => # Downloading pandas (11.8MiB)
#  => => # Downloading pyarrow (40.3MiB)
#  => => # Downloading numpy (16.0MiB)
#  => => # Downloading scikit-learn (12.3MiB)
# [+] Building 2.2s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  1.6s
#  => => # Resolved 16 packages in 431ms
#  => => # Downloading scipy (35.9MiB)
#  => => # Downloading pandas (11.8MiB)
#  => => # Downloading pyarrow (40.3MiB)
#  => => # Downloading numpy (16.0MiB)
#  => => # Downloading scikit-learn (12.3MiB)
# [+] Building 2.4s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  1.7s
#  => => # Resolved 16 packages in 431ms
#  => => # Downloading scipy (35.9MiB)
#  => => # Downloading pandas (11.8MiB)
#  => => # Downloading pyarrow (40.3MiB)
#  => => # Downloading numpy (16.0MiB)
#  => => # Downloading scikit-learn (12.3MiB)
# [+] Building 2.4s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  1.7s
#  => => # Resolved 16 packages in 431ms
#  => => # Downloading scipy (35.9MiB)
#  => => # Downloading pandas (11.8MiB)
#  => => # Downloading pyarrow (40.3MiB)
#  => => # Downloading numpy (16.0MiB)
#  => => # Downloading scikit-learn (12.3MiB)
# [+] Building 2.5s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  1.9s
#  => => # Resolved 16 packages in 431ms
#  => => # Downloading scipy (35.9MiB)
#  => => # Downloading pandas (11.8MiB)
#  => => # Downloading pyarrow (40.3MiB)
#  => => # Downloading numpy (16.0MiB)
#  => => # Downloading scikit-learn (12.3MiB)
# [+] Building 2.5s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  1.9s
#  => => # Resolved 16 packages in 431ms
#  => => # Downloading scipy (35.9MiB)
#  => => # Downloading pandas (11.8MiB)
#  => => # Downloading pyarrow (40.3MiB)
#  => => # Downloading numpy (16.0MiB)
#  => => # Downloading scikit-learn (12.3MiB)
# [+] Building 2.7s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  2.0s
#  => => # Resolved 16 packages in 431ms
#  => => # Downloading scipy (35.9MiB)
#  => => # Downloading pandas (11.8MiB)
#  => => # Downloading pyarrow (40.3MiB)
#  => => # Downloading numpy (16.0MiB)
#  => => # Downloading scikit-learn (12.3MiB)
# [+] Building 2.7s (9/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
# ...
# [+] Building 10.6s (12/13)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  8.4s
#  => [7/8] COPY [scoring.py, ./]                                            0.1s
#  => [8/8] RUN mkdir -p output                                              0.3s
#  => exporting to image                                                     1.2s
#  => => exporting layers                                                    1.2s
# [+] Building 10.8s (12/13)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  8.4s
#  => [7/8] COPY [scoring.py, ./]                                            0.1s
#  => [8/8] RUN mkdir -p output                                              0.3s
#  => exporting to image                                                     1.4s
#  => => exporting layers                                                    1.4s
# [+] Building 10.9s (12/13)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  8.4s
#  => [7/8] COPY [scoring.py, ./]                                            0.1s
#  => [8/8] RUN mkdir -p output                                              0.3s
#  => exporting to image                                                     1.5s
#  => => exporting layers                                                    1.5s
# [+] Building 11.1s (12/13)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  8.4s
#  => [7/8] COPY [scoring.py, ./]                                            0.1s
#  => [8/8] RUN mkdir -p output                                              0.3s
#  => exporting to image                                                     1.7s
#  => => exporting layers                                                    1.7s
# [+] Building 11.2s (12/13)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  8.4s
#  => [7/8] COPY [scoring.py, ./]                                            0.1s
#  => [8/8] RUN mkdir -p output                                              0.3s
#  => exporting to image                                                     1.8s
#  => => exporting layers                                                    1.8s
# [+] Building 11.4s (12/13)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  8.4s
#  => [7/8] COPY [scoring.py, ./]                                            0.1s
#  => [8/8] RUN mkdir -p output                                              0.3s
#  => exporting to image                                                     2.0s
#  => => exporting layers                                                    2.0s
# [+] Building 11.5s (12/13)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  8.4s
#  => [7/8] COPY [scoring.py, ./]                                            0.1s
#  => [8/8] RUN mkdir -p output                                              0.3s
#  => exporting to image                                                     2.1s
#  => => exporting layers                                                    2.1s
# [+] Building 11.7s (12/13)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  8.4s
#  => [7/8] COPY [scoring.py, ./]                                            0.1s
#  => [8/8] RUN mkdir -p output                                              0.3s
#  => exporting to image                                                     2.2s
#  => => exporting layers                                                    2.2s
# [+] Building 11.8s (12/13)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  8.4s
#  => [7/8] COPY [scoring.py, ./]                                            0.1s
#  => [8/8] RUN mkdir -p output                                              0.3s
#  => exporting to image                                                     2.4s
#  => => exporting layers                                                    2.4s
# [+] Building 11.9s (12/13)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  8.4s
#  => [7/8] COPY [scoring.py, ./]                                            0.1s
#  => [8/8] RUN mkdir -p output                                              0.3s
#  => exporting to image                                                     2.5s
#  => => exporting layers                                                    2.5s
# [+] Building 12.0s (13/13) FINISHED                              docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 442B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/8] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 67B                                           0.0s
#  => CACHED [2/8] RUN pip install -U pip                                    0.0s
#  => CACHED [3/8] RUN pip install uv                                        0.0s
#  => CACHED [4/8] WORKDIR /app                                              0.0s
#  => CACHED [5/8] COPY [requirements.txt, ./]                               0.0s
#  => [6/8] RUN uv pip install --system -r requirements.txt                  8.4s
#  => [7/8] COPY [scoring.py, ./]                                            0.1s
#  => [8/8] RUN mkdir -p output                                              0.3s
#  => exporting to image                                                     2.5s
#  => => exporting layers                                                    2.5s
#  => => writing image sha256:8b2ec433ac63a4f03327150442a795df43a3ce7d6c4a3  0.0s
#  => => naming to docker.io/library/taxi-duration-prediction                0.0s

# %%
# Run the container
# !docker run --rm taxi-duration-prediction
# Out:
# The mean predicted duration is 0.189 minutes

# %% [markdown]
# ## Bonus: upload the result to the cloud (Not graded)
# Just printing the mean duration inside the docker image doesn't seem very practical. Typically, after creating the output file, we upload it to the cloud storage.
#
# Modify your code to upload the parquet file to S3/GCS/etc.

# %% [markdown]
# ## Bonus: Use an orchestrator for batch inference
# Here we didn't use any orchestration. In practice we usually do.
#
# Split the code into logical code blocks
# Use a workflow orchestrator for the code execution

# %% [markdown]
# ## Publishing the image to dockerhub
# This is how we published the image to Docker hub:
#
# docker build -t mlops-zoomcamp-model:2024-3.10.13-slim .
# docker tag mlops-zoomcamp-model:2024-3.10.13-slim agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim
#
# docker login --username USERNAME
# docker push agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim
